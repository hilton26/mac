# %% [markdown]
# ### Useful Python Links

# %% [markdown]
# #### Python
#
# df.to_excel
# https://www.codegrepper.com/code-examples/python/df.to_excel
#
# How to Convert NumPy Array to Pandas DataFrame
# https://datatofish.com/numpy-array-to-pandas-dataframe/
#
# Interacting with Excel from a Jupyter notebook
# https://docs.xlwings.org/en/stable/quickstart.html
#
# From pandas to excel via xlwings - do not deposit index
# https://stackoverflow.com/questions/33020656/from-pandas-to-excel-via-xlwings-do-not-deposit-index
#
# Progress indicator during pandas operations
# https://stackoverflow.com/questions/18603270/progress-indicator-during-pandas-operations
#
# Progress Bars in Python (and pandas!)
# https://towardsdatascience.com/progress-bars-in-python-and-pandas-f81954d33bae
#
# How to remove commas from ALL the columns in pandas at once
# https://stackoverflow.com/questions/56947333/how-to-remove-commas-from-all-the-column-in-pandas-at-once
#
# Copy formula from one cell to another using openpyxl
# https://stackoverflow.com/questions/41931751/copy-formula-from-one-cell-to-another-using-openpyxl
#
# How to iterate over rows in a DataFrame in Pandas
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
#
# Excel hyperlink not working "cannot open the specified file"
# https://stackoverflow.com/questions/69724600/excel-hyperlink-not-working-cannot-open-the-specified-file?rq=1
#
# How to delete the contents of a folder?
# https://stackoverflow.com/questions/185936/how-to-delete-the-contents-of-a-folder
#
# xlwings: how to sort excel table with headers?
# https://stackoverflow.com/questions/48735167/xlwings-how-to-sort-excel-table-with-headers
#
# how to convert xls to xlsx
# https://stackoverflow.com/questions/9918646/how-to-convert-xls-to-xlsx
#
# Become an Excel Wizard With Python
# https://www.youtube.com/watch?v=q6Mc_sAPZ2Y
#
# Python 3 Quick Tip: The easy way to deal with file paths on Windows, Mac and Linux
# https://medium.com/@ageitgey/python-3-quick-tip-the-easy-way-to-deal-with-file-paths-on-windows-mac-and-linux-11a072b58d5f
#
# Openpyxl: Removing Duplicate cells from a column
# https://stackoverflow.com/questions/42372968/openpyxl-removing-duplicate-cells-from-a-column
#
# How to Perform a SUMIF Function in Pandas?
# https://www.geeksforgeeks.org/how-to-perform-a-sumif-function-in-pandas/
#
# How do I get the row count of a Pandas DataFrame?
# https://stackoverflow.com/questions/15943769/how-do-i-get-the-row-count-of-a-pandas-dataframe
#
# How can I extract the nth row of a pandas data frame as a pandas data frame?
# https://stackoverflow.com/questions/46307490/how-can-i-extract-the-nth-row-of-a-pandas-data-frame-as-a-pandas-data-frame
#
# Pandas loc vs. iloc vs. at vs. iat?
# https://re-thought.com/how-to-change-or-update-a-cell-value-in-python-pandas-dataframe/
#
# Replacing column values in a pandas DataFrame
# https://stackoverflow.com/questions/23307301/replacing-column-values-in-a-pandas-dataframe
#
# Update a dataframe within apply after using groupby
# https://stackoverflow.com/questions/43926479/update-a-dataframe-within-apply-after-using-groupby
#
# Python strftime - date without leading 0?
# Source: https://stackoverflow.com/questions/904928/python-strftime-date-without-leading-0
#
# Formatting dates in Python
# https://www.geeksforgeeks.org/formatting-dates-in-python/
#
# Difference between two dates in Python
# https://stackoverflow.com/questions/8419564/difference-between-two-dates-in-python
#
# How can I subtract a day from a Python date?
# https://www.tutorialspoint.com/How-can-I-subtract-a-day-from-a-Python-date#:~:text=You%20can%20subtract%20a%20day,subtract%20it%20from%20the%20date
#
# Accessing elements of pandas series
# https://www.geeksforgeeks.org/accessing-elements-of-a-pandas-series/
#
# Tutorial: Advanced For Loops in Python (Looping through a series by label):
# https://www.dataquest.io/blog/tutorial-advanced-for-loops-python-pandas/
#
# Python - List Comprehension
# https://www.w3schools.com/python/python_lists_comprehension.asp
#
# Pandas - Multiplying Columns To Make A New Column
# https://www.youtube.com/watch?v=0MvYbrKMCKA
#
# Pandas replace column values with a list
# https://stackoverflow.com/questions/44608524/pandas-replace-column-values-with-a-list
#
# Exporting a Pandas DataFrame to an Excel file
# https://www.geeksforgeeks.org/exporting-a-pandas-dataframe-to-an-excel-file/
#
# Export from pandas to_excel without row names (index)? https://stackoverflow.com/questions/22089317/export-from-pandas-to-excel-without-row-names-index

# %% [markdown]
# #### Selenium
# How To Handle Dropdown with Select In Selenium With Python- Selenium Webdriver Tutorial Python (YouTube Video #7)
# Source: https://www.youtube.com/watch?v=p9NpddaIZWs
#
# Selenium Course for Beginners - Web Scraping Bots, Browser Automation, Testing (Tutorial) (Aug 2021)
# Source: https://www.youtube.com/watch?v=j7VZsCCnptM&list=RDCMUC8butISFwT-Wl7EV0hUK0BQ&start_radio=1&rv=j7VZsCCnptM&t=1520
#
# How to change the value of datepicker using Selenium and Python
# Source: https://stackoverflow.com/questions/62911531/how-to-change-the-value-of-datepicker-using-selenium-and-python
#
# Inserting values into strings
# Source: https://matthew-brett.github.io/teaching/string_formatting.html#:~:text=If%20you%20can%20depend%20on,variable%20names%20within%20the%20string.
#
# Python strftime - date without leading 0?
# Source: https://stackoverflow.com/questions/904928/python-strftime-date-without-leading-0
#
# Most Exhaustive WebDriver Locators Cheat Sheet
# Source: https://www.automatetheplanet.com/selenium-webdriver-locators-cheat-sheet/
#
# Filling in Web Forms
# Source: https://iqss.github.io/dss-webscrape/filling-in-web-forms.html
#
# Error message from Chrome when internet / network is not available:
# "WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED"
#
# Source: stackoverflow Selenium / Python - Selecting via css selector
# https://stackoverflow.com/questions/18600391/selenium-python-selecting-via-css-selector
#
# Selenium - 5. Waits
# https://selenium-python.readthedocs.io/waits.html
#
# Python 3's f-Strings: An Improved String Formatting Syntax (Guide)
# https://realpython.com/python-f-strings/
#
# How to switch to new window in Selenium for Python?
# https://stackoverflow.com/questions/10629815/how-to-switch-to-new-window-in-selenium-for-python
#
# WebDriverException: Message: unknown error: cannot find Opera binary
# https://stackoverflow.com/questions/52793537/selenium-common-exceptions-webdriverexception-message-unknown-error-cannot-fi
