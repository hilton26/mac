# %% [markdown]
# ### Turn An Excel Sheet Into An Interactive Dashboard Using Python (Streamlit)
# https://www.youtube.com/watch?v=Sb0A9i6d320

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.15.1-py2.py3-none-any.whl (10.3 MB)
# Requirement already satisfied: python-dateutil in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (9.0.1)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-10.0.1-cp39-cp39-win_amd64.whl (20.3 MB)
# Requirement already satisfied: requests>=2.4 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (2.27.1)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: toml in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: numpy in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (3.19.1)
# Requirement already satisfied: cachetools>=4.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (4.1.1)
# Collecting rich>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
# Requirement already satisfied: click>=7.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: packaging>=14.1 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: tornado>=5.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: watchdog in c:\users\hilton.netta\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: entrypoints in c:\users\hilton.netta\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in c:\users\hilton.netta\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: jinja2 in c:\users\hilton.netta\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (4.4.0)
# Requirement already satisfied: colorama in c:\users\hilton.netta\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.4)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\hilton.netta\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.7.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hilton.netta\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hilton.netta\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hilton.netta\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\hilton.netta\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hilton.netta\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hilton.netta\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hilton.netta\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.9)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.11.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\hilton.netta\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\hilton.netta\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py): started
#   Building wheel for validators (setup.py): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19582 sha256=a09e75bc4dac2fd363b184fa5d4524eeba0d17f491ed01aed130547244e29543
#   Stored in directory: c:\users\hilton.netta\appdata\local\pip\cache\wheels\2d\f0\a8\1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: smmap, gitdb, commonmark, validators, semver, rich, pympler, pydeck, pyarrow, gitpython, blinker, altair, streamlit
# Successfully installed altair-4.2.0 blinker-1.5 commonmark-0.9.1 gitdb-4.0.10 gitpython-3.1.29 pyarrow-10.0.1 pydeck-0.8.0 pympler-1.0.1 rich-12.6.0 semver-2.13.0 smmap-5.0.0 streamlit-1.15.1 validators-0.20.0

# %%
# !pip install plotly-express
# Out:
# Collecting plotly-express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from plotly-express) (1.4.2)
# Requirement already satisfied: scipy>=0.18 in c:\users\hilton.netta\anaconda3\lib\site-packages (from plotly-express) (1.7.3)
# Requirement already satisfied: numpy>=1.11 in c:\users\hilton.netta\anaconda3\lib\site-packages (from plotly-express) (1.21.5)
# Requirement already satisfied: patsy>=0.5 in c:\users\hilton.netta\anaconda3\lib\site-packages (from plotly-express) (0.5.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from plotly-express) (0.13.2)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from plotly-express) (5.6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hilton.netta\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly-express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hilton.netta\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly-express) (2021.3)
# Requirement already satisfied: six in c:\users\hilton.netta\anaconda3\lib\site-packages (from patsy>=0.5->plotly-express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hilton.netta\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly-express) (8.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\hilton.netta\anaconda3\lib\site-packages (from statsmodels>=0.9.0->plotly-express) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hilton.netta\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.9.0->plotly-express) (3.0.4)
# Installing collected packages: plotly-express
# Successfully installed plotly-express-0.4.1

# %%
import pandas as pd # !pip install pandas, openpyxl
import plotly.express as px # !pip install plotly-express
import streamlit as st # !pip install streamlit

# %%
pth = r'P:\Working Folders\Hilton\W'
df = pd.read_excel(
    io = pth + '\supermarkt_sales.xlsx',
    engine = 'openpyxl',
    sheet_name = 'Sales',
    skiprows = 3,
    usecols = 'B:R',
    nrows = 1000,)

# %%
df
# Out:
#       Invoice ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date      Time      Payment    cogs  gross margin percentage  \
# 0   2021-01-05  13:08:00      Ewallet  522.83                 4.761905
# 1   2021-03-08  10:29:00         Cash   76.40                 4.761905
# 2   2021-03-03  13:23:00  Credit card  324.31                 4.761905
# 3   2021-01-27  20:33:00      Ewallet  465.76                 4.761905
# 4   2021-02-08  10:37:00      Ewallet  604.17                 4.761905
# ..         ...       ...          ...     ...                      ...
# 995 2021-01-29  13:46:00      Ewallet   40.35                 4.761905
# 996 2021-03-02  17:16:00      Ewallet  973.80                 4.761905
# 997 2021-02-09  13:22:00         Cash   31.84                 4.761905
# 998 2021-02-22  15:33:00         Cash   65.82                 4.761905
# 999 2021-02-18  13:28:00         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]
